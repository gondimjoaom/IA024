# %%
import pandas as pd
import numpy as np
import seaborn as sns
from tqdm.notebook import tqdm
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("sdg_index_2000-2022_TARGET=next10years.csv",)

# %%
data = data.dropna()

# %%
data
# Out:
#      country_code      country  year  sdg_index_score  goal_1_score  \
# 0             AFG  Afghanistan  2000             36.0          28.8
# 1             AFG  Afghanistan  2001             36.3          28.8
# 2             AFG  Afghanistan  2002             36.3          28.8
# 3             AFG  Afghanistan  2003             36.7          28.8
# 4             AFG  Afghanistan  2004             37.1          28.8
# ...           ...          ...   ...              ...           ...
# 4125          ZWE     Zimbabwe  2008             51.9          31.3
# 4126          ZWE     Zimbabwe  2009             52.9          31.3
# 4127          ZWE     Zimbabwe  2010             53.8          31.3
# 4128          ZWE     Zimbabwe  2011             53.8          31.3
# 4129          ZWE     Zimbabwe  2012             55.8          39.8
#
#       goal_2_score  goal_3_score  goal_4_score  goal_5_score  goal_6_score  \
# 0             27.3          19.2           1.6          20.8          32.4
# 1             30.6          19.4           1.6          20.8          32.4
# 2             30.7          19.7           1.6          20.8          32.7
# 3             32.5          19.9           1.6          20.8          33.0
# 4             32.1          21.1           1.6          20.8          33.3
# ...            ...           ...           ...           ...           ...
# 4125          40.2          17.9          60.2          64.2          55.1
# 4126          44.0          19.5          60.2          64.6          54.9
# 4127          43.5          24.8          60.2          65.2          54.6
# 4128          43.1          27.1          60.2          65.8          54.3
# 4129          45.9          29.5          65.4          66.3          54.1
#
#       ...  goal_9_score  goal_10_score  goal_11_score  goal_12_score  \
# 0     ...           5.2            0.0           25.8           94.7
# 1     ...           5.2            0.0           25.8           94.5
# 2     ...           5.2            0.0           26.1           94.1
# 3     ...           5.2            0.0           26.5           94.4
# 4     ...           5.2            0.0           26.8           94.8
# ...   ...           ...            ...            ...            ...
# 4125  ...          14.0           37.0           62.7           94.9
# 4126  ...          14.0           37.0           70.0           94.7
# 4127  ...          15.1           37.0           71.0           94.7
# 4128  ...          17.1           37.0           73.6           93.4
# 4129  ...          20.2           37.0           71.3           93.6
#
#       goal_13_score  goal_14_score  goal_15_score  goal_16_score  \
# 0              99.4            0.0           51.9           39.2
# 1              99.4            0.0           51.9           39.2
# 2              99.4            0.0           51.8           39.2
# 3              99.4            0.0           51.8           39.2
# 4              99.4            0.0           51.8           39.2
# ...             ...            ...            ...            ...
# 4125           97.8            0.0           73.9           43.2
# 4126           97.8            0.0           73.9           44.3
# 4127           97.7            0.0           73.9           44.9
# 4128           95.3            0.0           73.9           44.1
# 4129           94.9            0.0           73.8           45.7
#
#       goal_17_score  sdg_index_score_next_10_years
# 0              34.2                           38.8
# 1              34.2                           38.4
# 2              34.2                           39.7
# 3              34.2                           39.7
# 4              34.2                           40.8
# ...             ...                            ...
# 4125           38.0                           55.9
# 4126           38.0                           53.7
# 4127           45.9                           54.3
# 4128           45.9                           54.8
# 4129           53.0                           55.6
#
# [2340 rows x 22 columns]

# %%
data.iloc[:, 4:-1]
# Out:
#       goal_1_score  goal_2_score  goal_3_score  goal_4_score  goal_5_score  \
# 0             28.8          27.3          19.2           1.6          20.8
# 1             28.8          30.6          19.4           1.6          20.8
# 2             28.8          30.7          19.7           1.6          20.8
# 3             28.8          32.5          19.9           1.6          20.8
# 4             28.8          32.1          21.1           1.6          20.8
# ...            ...           ...           ...           ...           ...
# 4125          31.3          40.2          17.9          60.2          64.2
# 4126          31.3          44.0          19.5          60.2          64.6
# 4127          31.3          43.5          24.8          60.2          65.2
# 4128          31.3          43.1          27.1          60.2          65.8
# 4129          39.8          45.9          29.5          65.4          66.3
#
#       goal_6_score  goal_7_score  goal_8_score  goal_9_score  goal_10_score  \
# 0             32.4          21.0          38.5           5.2            0.0
# 1             32.4          22.3          38.5           5.2            0.0
# 2             32.7          21.5          38.4           5.2            0.0
# 3             33.0          24.5          38.4           5.2            0.0
# 4             33.3          28.0          38.5           5.2            0.0
# ...            ...           ...           ...           ...            ...
# 4125          55.1          39.7          60.8          14.0           37.0
# 4126          54.9          42.3          60.8          14.0           37.0
# 4127          54.6          40.1          60.7          15.1           37.0
# 4128          54.3          38.7          60.5          17.1           37.0
# 4129          54.1          41.4          60.6          20.2           37.0
#
#       goal_11_score  goal_12_score  goal_13_score  goal_14_score  \
# 0              25.8           94.7           99.4            0.0
# 1              25.8           94.5           99.4            0.0
# 2              26.1           94.1           99.4            0.0
# 3              26.5           94.4           99.4            0.0
# 4              26.8           94.8           99.4            0.0
# ...             ...            ...            ...            ...
# 4125           62.7           94.9           97.8            0.0
# 4126           70.0           94.7           97.8            0.0
# 4127           71.0           94.7           97.7            0.0
# 4128           73.6           93.4           95.3            0.0
# 4129           71.3           93.6           94.9            0.0
#
#       goal_15_score  goal_16_score  goal_17_score
# 0              51.9           39.2           34.2
# 1              51.9           39.2           34.2
# 2              51.8           39.2           34.2
# 3              51.8           39.2           34.2
# 4              51.8           39.2           34.2
# ...             ...            ...            ...
# 4125           73.9           43.2           38.0
# 4126           73.9           44.3           38.0
# 4127           73.9           44.9           45.9
# 4128           73.9           44.1           45.9
# 4129           73.8           45.7           53.0
#
# [2340 rows x 17 columns]

# %%
X = data.iloc[:, 4:-1]
Y = data.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error

# %%
r2s, maes, rmses = [], [], []
coefs_matrix = []
for i in tqdm(range(1, 101)):
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=i)
    regr = RandomForestRegressor(max_depth=10, random_state=0)
    regr.fit(X_train, y_train)
    y_pred = regr.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    r2s.append(r2)
    maes.append(mean_absolute_error(y_test, y_pred))
    rmses.append(root_mean_squared_error(y_test, y_pred))
    coefs_matrix.append(regr.feature_importances_)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
np.mean(r2s)
# Out:
# 0.9878141253103359

# %%
coefs_matrix = np.array(coefs_matrix)
df_coefs = pd.DataFrame(coefs_matrix, columns=X_train.columns)

# %%
fig, ax = plt.subplots(figsize=(13,5))
b = sns.boxplot(df_coefs)
ax.tick_params(axis='x', rotation=45)

# %% [markdown]
# ## Removendo feature goal_3

# %%
remove = ["goal_3_score"]
r2s, maes, rmses = [], [], []
coefs_matrix = []
for i in tqdm(range(1, 101)):
    X_train, X_test, y_train, y_test = train_test_split(X[[feat for feat in X.columns if feat not in remove]],
                                                        Y, test_size=0.3, random_state=i)
    regr = RandomForestRegressor(max_depth=10, random_state=0)
    regr.fit(X_train, y_train)
    y_pred = regr.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    r2s.append(r2)
    maes.append(mean_absolute_error(y_test, y_pred))
    rmses.append(root_mean_squared_error(y_test, y_pred))
    coefs_matrix.append(regr.feature_importances_)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
np.mean(r2s), np.mean(maes), np.mean(rmses)
# Out:
# (0.9881124837484906, 0.845116874300895, 1.1411049895498468)

# %%
coefs_matrix = np.array(coefs_matrix)
df_coefs = pd.DataFrame(coefs_matrix, columns=X_train.columns)

# %%
fig, ax = plt.subplots(figsize=(13,5))
b = sns.boxplot(df_coefs)
ax.tick_params(axis='x', rotation=45)

# %% [markdown]
# ## Removendo feature goal_7

# %%
remove = ["goal_3_score", "goal_7_score"]
r2s, maes, rmses = [], [], []
coefs_matrix = []
for i in tqdm(range(1, 101)):
    X_train, X_test, y_train, y_test = train_test_split(X[[feat for feat in X.columns if feat not in remove]],
                                                        Y, test_size=0.3, random_state=i)
    regr = RandomForestRegressor(max_depth=10, random_state=0)
    regr.fit(X_train, y_train)
    y_pred = regr.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    r2s.append(r2)
    maes.append(mean_absolute_error(y_test, y_pred))
    rmses.append(root_mean_squared_error(y_test, y_pred))
    coefs_matrix.append(regr.feature_importances_)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
np.mean(r2s), np.mean(maes), np.mean(rmses)
# Out:
# (0.9862519715601078, 0.8932256867741031, 1.2265051466472146)

# %%
coefs_matrix = np.array(coefs_matrix)
df_coefs = pd.DataFrame(coefs_matrix, columns=X_train.columns)

# %%
fig, ax = plt.subplots(figsize=(13,5))
b = sns.boxplot(df_coefs)
ax.tick_params(axis='x', rotation=45)

# %% [markdown]
# ## Removendo feature goal_4

# %%
remove = ["goal_3_score", "goal_7_score", "goal_4_score"]
r2s, maes, rmses = [], [], []
coefs_matrix = []
for i in tqdm(range(1, 101)):
    X_train, X_test, y_train, y_test = train_test_split(X[[feat for feat in X.columns if feat not in remove]],
                                                        Y, test_size=0.3, random_state=i)
    regr = RandomForestRegressor(max_depth=10, random_state=0)
    regr.fit(X_train, y_train)
    y_pred = regr.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    r2s.append(r2)
    maes.append(mean_absolute_error(y_test, y_pred))
    rmses.append(root_mean_squared_error(y_test, y_pred))
    coefs_matrix.append(regr.feature_importances_)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
np.mean(r2s), np.mean(maes), np.mean(rmses)
# Out:
# (0.9920828218030775, 0.7050733693868216, 0.9552484971942736)

# %%
coefs_matrix = np.array(coefs_matrix)
df_coefs = pd.DataFrame(coefs_matrix, columns=X_train.columns)

# %%
fig, ax = plt.subplots(figsize=(13,5))
b = sns.boxplot(df_coefs)
ax.tick_params(axis='x', rotation=45)
